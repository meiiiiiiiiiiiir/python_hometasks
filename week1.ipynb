# %%
print("hello,world") #1
# Out:
# hello,world

# %%
print("Meyirzhan")    #2
# Out:
# Meyirzhan

# %%
a=5   #3
print(a)
# Out:
# 5

# %%
a="hihihaha"   #4
print(a)
# Out:
# hihihaha

# %%
a=8
s=5
print(a+s)    #5
print(a-s)    #6
print(a+s)    #7
print(a/s)    #8
print(a%s)    #9
# Out:
# 13
# 3
# 13
# 1.6
# 3

# %%
a=6     #10
print(a**3)
# Out:
# 216

# %%
a=input("what is your name")      #11
print("hello,"+a)
# Out:
# hello,meyir

# %%
a=int(input())       #12
s=int(input())
print(a+s)
# Out:
# 9

# %%
a=int(input("what is your age"))      #13
s=10
print(a+s)
# Out:
# 62

# %%
a=int(input())
print(a**2)      #14
print(a**3)      #15
print(a/2)        #16
print(a*10)        #17
# Out:
# 8836
# 830584
# 47.0
# 940

# %%
a=7
q=8
s=9
print(a+q+s)         #18
print((a+s+q)/3)     #19
# Out:
# 24
# 8.0

# %%
a=5
p=a*4
s=a**2
print(p)        #20
print(s)        #21
# Out:
# 20
# 25

# %%
a=7
b=4
s=a*b
p=(a+b)*2
print(p)     #23
print(s)      #22
# Out:
# 22
# 28

# %%
p=3.14
r=5
s=p*r**2
l=2*p*r
print(l)      #25
print(s)       #24
# Out:
# 31.400000000000002
# 78.5

# %%
a=8
h=10
s=0.5*a*h
print(s)       #26
# Out:
# 40.0

# %%
a=9
v=a**3
print(v)          #27
# Out:
# 729

# %%
a=7
b=4
c=6
v=a*b*c
print(v)           #28
# Out:
# 168

# %%
p=3.14
r=5
v=4/3*p*r**3
print(v)
# Out:
# 523.3333333333334

# %%
l=600
s=l/100
print(s)          #30
# Out:
# 6.0

# %%
l=5
s=l*1000
print(s)       #31
# Out:
# 5000

# %%
s=651681
m=s/60
c=m/60
print(m)             #32
print(c)
# Out:
# 10861.35
# 181.0225

# %%
r=660
d=r/90
print(d)#33
# Out:
# 7.333333333333333

# %%
d=20
r=d*90
print(r)#34
# Out:
# 1800

# %%
t=25
T=t*33.8
print(T)#35
# Out:
# 844.9999999999999

# %%
T=900
t=T/33.8
print(t)#36
# Out:
# 26.627218934911244

# %%
s=500
t=50
v=s/t
print(v)#37
# Out:
# 10.0

# %%
t=100
v=15
s=v*t
print(s)#38
# Out:
# 1500

# %%
t=s/v
s=1000
v=20
print(t)#39
# Out:
# 100.0

# %%
a=int(input())
print(abs(a))#40
# Out:
# 16756565

# %%
a=input()
print(len(a))#41
# Out:
# 26

# %%
a=input()
s=input()
print(a+s)#42
# Out:
# holapppspslskfkmm

# %%
a=input()
s=int(input())
for i in range(s):
    print(a)#43
# Out:
# xixixaxa
# xixixaxa
# xixixaxa

# %%
a=input()
print(a[0])#44
# Out:
# v

# %%
a=input()
print(a[-1])#45
# Out:
# o

# %%
a=input()
print(a[2])#46
# Out:
# w

# %%
a=input()
print(a[:5])#47
# Out:
# ;ljer

# %%
a=input()
print(a[2:7])#48
# Out:
# cdefg

# %%
a=input()
print(a[::-1])#49
# Out:
# aloh

# %%
#50
a="i hate math"
x=a.upper()
print(x)
# Out:
# I HATE MATH

# %%
#51
a="I LOVE MATH"
z=a.lower()
print(z)
# Out:
# i love math

# %%
#52
a="what a wonderful world"
z=a.capitalize()
print(z)
# Out:
# What a wonderful world

# %%
#53
a="apples fall"
z=a.replace('a','o')
print(z)
# Out:
# opples foll

# %%
a="apples fall"
z=a.count("a")    #54
print(z)
# Out:
# 2

# %%
a="apples fall"   #55
z=a.count(" ")
print(z)
# Out:
# 1

# %%
a="apples fall"    #56
z=a.replace(' ','')
print(z)
# Out:
# applesfall

# %%
a=input("what is your name")
s=int(input())                #57
for i in range(s):
    print(a)
# Out:
# meyirzhan
# meyirzhan
# meyirzhan
# meyirzhan
# meyirzhan

# %%
a = input("what is your name")   #58
q = input("what is your surname")
print(a+" "+q)
# Out:
# meyirzhan tolesh

# %%
#59
print("<hihihaha>")
# Out:
# <hihihaha>

# %%
#60
print("<менің атым ______,жасым ________>")
# Out:
# <менің атым ______,жасым ________>

# %%
#61
a=371
print(str(a))
# Out:
# 371

# %%
a="048"          #62
print(int(a))
# Out:
# 48

# %%
#63
a=4.646
print(int(a))
# Out:
# 4

# %%
#64
a=5.463632
print(round(a, 2))
# Out:
# 5.46

# %%
#65
a=2.42214
print(round(a))
# Out:
# 2

# %%
#66
a=8.8722942940
print(round(a, 2))
# Out:
# 8.87

# %%
#67
a="123"
print(int(a)+10)
# Out:
# 133

# %%
#68
a=45
print(str(a)+ "kg")
# Out:
# 45kg

# %%
a=4.5  #69
print(a+0.5)
# Out:
# 5.0

# %%
#70
a=4
s=5.77969964
print(a+s)
# Out:
# 9.77969964

# %%
#71
a=346264572
s="people"
print(str(a)+" "+s)
# Out:
# 346264572 people

# %%
#72
a=1000000000000
q=a/100
print(str(q))
# Out:
# 10000000000.0

# %%
#73
a=40956
print(type(a))
# Out:
# <class 'int'>

# %%
#74
a=3.035491309854103945
print(type(a))
# Out:
# <class 'float'>

# %%
#75
a="dtfdjyfjhg"
print(type(a))
# Out:
# <class 'str'>

# %%
a=6            #76
z=934.8639680956
s="klarwrnl"
print(type(a))
print(type(z))
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a=1        #77
s=" year"
print(str(a)+s)
# Out:
# 1 year

# %%
#78
p=160
a=4
print(a*p)
# Out:
# 640

# %%
print(24*60*60)     #79
# Out:
# 86400

# %%
print(7*24*60)        #80
# Out:
# 10080

# %%
#81
a=45
print((a//10)+(a%10))
# Out:
# 9

# %%
a=345             #82
print((a//100)+(a//10)%10+(a%10))
# Out:
# 12

# %%
a = 345  #83
print((a//100)*((a//10)%10)*(a%10))
# Out:
# 60

# %%
#84
a=46
print((a%10)*10+a//10)
# Out:
# 64

# %%
#85
a=359
print(a//100)
print(a%10)#86
print(a//10)#87
print((a//10)%10)#88
# Out:
# 3
# 9
# 35
# 5

# %%
#89

# %%
#90
a=52
print(a%2==0)
# Out:
# True

# %%
#91
a=52
print(a%2!=0)
# Out:
# False

# %%
#92
a=123
print(a//10)
# Out:
# 12

# %%
a=121  #93
print(a**0.5)
# Out:
# 11.0

# %%
#94#95
a=3
b=4
s=0.5*a*b
c=(a**2+b**2)**0.5
print(s)
print(c)
# Out:
# 6.0
# 5.0

# %%
a=5             #96
b=9
h=4
s=(a+b)/2*h
print(s)
# Out:
# 28.0

# %%
a=5           #97
d=a*(2**0.5)
print(d)
# Out:
# 7.0710678118654755

# %%
a=5     #98
b=7
d=(a**2+b**2)**0.5
print(d)
# Out:
# 8.602325267042627

# %%
#99
p=3.14
r=5
h=10
v=p*r**2*h
print(v)
# Out:
# 785.0

# %%
p=3.14       #100
r=4
h=9
v=(p*r**2*h)/3
print(v)
# Out:
# 150.72
