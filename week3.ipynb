# %%
#1   #11
a=int(input())
if a%2==0:
    print("zhup san")
else:
    print("tak san")
# Out:
# zhup san

# %%
#2
a=int(input())
if a>=0:
    print("pozitive")
else:
    print("negative")
# Out:
# negative

# %%
#3     #7
a=int(input())
if a==0:
    print("zero")
else:
    print("not zero")
# Out:
# not zero

# %%
#4
a=int(input())
b=int(input())
if a==b:
    print("ten")
else:
    print("ten emes")
# Out:
# ten

# %%
#5
a=int(input())
if a>=18:
    print("ala alasyz")
else:
    print("zhas zhetkiliksiz")
# Out:
# zhas zhetkiliksiz

# %%
#6
a=int(input())
if a%3==0:
    print("boluge bolady")
else:
    print("bolinbeidi")
# Out:
# boluge bolady

# %%
#8
a=int(input())
if a>30:
    print("zhogary")
elif a==30:
    print("ten")
else:
    print("tomen")
# Out:
# tomen

# %%
#9
a=int(input())
b=int(input())
if a>b:
    print("a en ulken")
elif a==b:
    print("ten")
else:
    print("b en ulken")
# Out:
# b en ulken

# %%
#10
a=int(input())
if 1<=a<=10:
    print("aralykka kiredy")
else:
    print("kirmeidy")
# Out:
# aralykka kiredy

# %%
#12
a=int(input())
if a%2==0 and a%5==0:
    print("true")
else:
    print("false")
# Out:
# false

# %%
#13
a=int(input())
if 1<=a<=100:
    print("aralykka kiredy")
else:
    print("kirmeidy")
# Out:
# aralykka kiredy

# %%
#14
a=int(input())
if a>=60:
    print("zhenildik bar")
else:
    print("zhok")
# Out:
# zhenildik bar

# %%
#15
a=int(input())
match a%2:
    case 0:
        print("zhup")
    case 1:
        print("tak")
# Out:
# zhup

# %%
#16    #23
a=int(input())
if a>0:
    print("pozitive")
elif a<0:
    print("negative")
else:
    print("zero")
# Out:
# pozitive

# %%
#17
a=int(input())
if a%7==0:
    print("bolinedi")
else:
    print("bolinbeidi")
# Out:
# bolinedi

# %%
#18
month=int(input())
match month:
    case 1:
        print("january")
    case 2:
        print("february")
    case 3:
        print("march")
    case 4:
        print("april")
    case 5:
        print("may")
    case 6:
        print("june")
    case 7:
        print("july")
    case 8:
        print("august")
    case 9:
        print("september")
    case 10:
        print("october")
    case 11:
        print("november")
    case 12:
        print("december")
# Out:
# may

# %%
#19
a=int(input())
b=int(input())
c=int(input())
print(max(a,b,c))
# Out:
# 9

# %%
#20
a=int(input())
if 22<=a<=55:
    print("intervalga kiredi")
else:
    print("kirmeidi")
# Out:
# kirmeidi

# %%
#21
a=int(input())
if 6<=a<12:
    print("tan")
elif 12<=a<18:
    print("kun")
elif 18<=a<24:
    print("kesh")
else:
    print("tun")
# Out:
# kesh

# %%
#22
a=int(input())
b=int(input())
c=int(input())
if a==b and b==c:
    print("tenkabyrgaly")
elif a==b or b==c or a==c:
    print("тенбуйирли")
else:
    print("ar tyrly kabyrgaly")
# Out:
# тенбуйирли

# %%
#24
a=int(input())
b=int(input())
print(min(a,b))
# Out:
# 7

# %%
#25              #32
a=int(input())
if a<18:
    print("jasospirim")
elif 18<=a<60:
    print("eresek")
else:
    print("kart")
# Out:
# eresek

# %%
#26
a=int(input())
b=int(input())
amal=input("amal engiz")
if amal=="+":
    print(a+b)
elif amal=="-":
    print(a-b)
else:
    print("kate")
# Out:
# 6

# %%
#27
a=int(input())
if a>=90:
    print("A")
elif 90<a<=80:
    print("B")
elif 80<a<=70:
    print("C")
elif 70<a<=60:
    print("D")
else:
    print("F")
# Out:
# F

# %%
#28
a=int(input())
match a:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case 3:
        print("wednesday")
    case 4:
        print("thursday")
    case 5:
        print("friday")
    case 6:
        print("saturday")
    case 7:
        print("sunday")

# %%
#29
a=int(input())
for i in range(2,a):
    if a%i==0:
        print("jai san emes")
        break
    else:
        print("jai san")
        break
# Out:
# jai san

# %%
#30
#16    #23
a = int(input())
if a > 0:
    print("pozitive")
elif a < 0:
    print("negative")
else:
    print("zero")
# Out:
# pozitive

# %%
#31
a=int(input())
b=int(input())
amal=input("amal engiz")
if amal=="+":
    print(a+b)
elif amal=="-":
    print(a-b)
elif amal=="*":
    print(a*b)
elif amal=="/":
    print(a/b)
else:
    print("kate")
# Out:
# 35

# %%
#33
a=int(input())
if a%4==0:
    print("kibise")
else:
    print("kibise emes")
# Out:
# kibise

# %%
#34
a=int(input())
b=int(input())
c=int(input())
print(sorted([a,b,c]))
# Out:
# [6, 9, 99]

# %%
#35
a = int(input())
if a>=5:
    print("500 tg")
elif 5<a<=10:
    print("800 tg")
else:
    print("1200 tg")
# Out:
# 500 tg

# %%
#36
a = int(input())
if a>=75:
    print("otti")
elif 75<a<=50:
    print("kaita tapsyry")
else:
    print("otpedy")
# Out:
# otpedy

# %%
#37
a=int(input())
b=int(input())
c=int(input())
d=int(input())
e=int(input())
print(max(a,b,c,d,e))
# Out:
# 55

# %%
#38
a=input()
if a.isdigit():
    print("san")
else:
    print("matin")
# Out:
# san

# %%
grade=int(input())   #40
match grade:
    case 1:
        print("ote jaman")
    case 2:
        print("jaman")
    case 3:
        print("ortasha")
    case 4:
        print("jaksy")
    case 5:
        print("ote jaksy")
# Out:
# ote jaksy

# %%
a=int(input())    #41
b=int(input())
op=input("operaation")
if op=="+":
    print(a+b)
elif op=="-":
    print(a-b)
elif op=="*":
    print(a*b)
elif op=="/":
    if b==0:
        print("0ge bolinbeidi")
    else:
        print(a/b)
else:
    print("wrong operation")
# Out:
# 17

# %%
age=int(input())   #42
if age<=7:
    print("free")
elif 7<age<=16:
    print("500 tg")
elif 16<age<=60:
    print("1000 tg")
else:
    print("600 tg")
# Out:
# 600 tg
