# %%
def salem_ber():  #1
    print("salem,alem!")
salem_ber()
salem_ber()
salem_ber()
salem_ber()
salem_ber()
# Out:
# salem,alem!
# salem,alem!
# salem,alem!
# salem,alem!
# salem,alem!

# %%
def kosu(a,b):      #2
    return a+b
print(kosu(8,5))
print(kosu(10,400))
print(kosu(5896,546))
# Out:
# 13
# 410
# 6442

# %%
#3
def tak_zhup(a):
    if a%2==0:
        return "zhup"
    else:
        return "tak"


print(tak_zhup(5))
print(tak_zhup(6))
# Out:
# tak
# zhup

# %%
#4
def keri_soz(a):
    return a[::-1]


print(keri_soz("jkicjheshdckiju"))
print(keri_soz("xixixixaxaxaxa"))
# Out:
# ujikcdhsehjcikj
# axaxaxaxixixix
