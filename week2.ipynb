# %%
#1
a=121
print(a**0.5)
# Out:
# 11.0

# %%
#2
a=5
b=4
print(a**b)
# Out:
# 625

# %%
#3
import math
a=5.945
print(math.floor(a))
# Out:
# 5

# %%
#4
import math
a=4.56
print(math.ceil(a))
# Out:
# 5

# %%
#5
import math
a=-5545
print(math.fabs(a))
# Out:
# 5545.0

# %%
#6
import math
a=6
print(math.factorial(a))
# Out:
# 720

# %%
#7
import math
print(round(math.pi,5))
# Out:
# 3.14159

# %%
#8
import math
print(round(math.e,5))
# Out:
# 2.71828

# %%
#9
import math
a=1
b=-5
c=4
d=math.sqrt(b**2-4*a*c)
x1=(-b+d)/(2*a)
x2=(-b-d)/(2*a)
print(x1,x2)
# Out:
# 4.0 1.0

# %%
#10
import math
a=5
b=12
c=math.sqrt(a**2+b**2)
print(c)
# Out:
# 13.0

# %%
#11
import math
n=100
print(math.log10(n))
# Out:
# 2.0

# %%
#12
import math
n=100
print(math.log(n,math.e))
# Out:
# 4.605170185988092

# %%
#13
import math
n=100
a=2
print(math.log(n,a))
# Out:
# 6.643856189774725

# %%
#14
import math
s=4
print(math.exp(s))
# Out:
# 54.598150033144236

# %%
#15
import math
r=5
s=math.pi*r**2
print(s)
# Out:
# 78.53981633974483

# %%
#16
import math
a=3
r=math.radians(a)
print(math.sin(r))
# Out:
# 0.052335956242943835

# %%
#17
import math
a=30
r=math.radians(a)
print(math.cos(r))
# Out:
# 0.8660254037844387

# %%
#18
import math
a=300
r=math.radians(a)
print(math.tan(r))
# Out:
# -1.732050807568877

# %%
#19
import math
a=1
print(math.degrees(math.asin(a)))
# Out:
# 90.0

# %%
#20
a=-1
print(math.degrees(math.acos(a)))
# Out:
# 180.0

# %%
#21
a=0
print(math.degrees(math.atan(a)))
# Out:
# 0.0

# %%
#22
x=int(input())
y=int(input())
print(math.degrees(math.atan2(x,y)))
# Out:
# 33.690067525979785

# %%
#23
a=4
b=5
print(math.sqrt(a*b))
# Out:
# 4.47213595499958

# %%
#24
a=150
print(math.radians(a))
# Out:
# 2.6179938779914944

# %%
#25
a=1.57
print(math.degrees(a))
# Out:
# 89.95437383553924

# %%
#26
r=4
print(r*math.pi*2)
# Out:
# 25.132741228718345

# %%
#27
r=5
a=45
s=(math.pi*r**2*a)/360
print(s)
# Out:
# 9.817477042468104

# %%
#28
a=500000
s=5
print(a**(1/s))
# Out:
# 13.79729661461215

# %%
#29
x1=int(input())
x2=int(input())
y1=int(input())
y2=int(input())
print(math.sqrt((x2-x1)**2+(y2-y1)**2))
# Out:
# 7.280109889280518

# %%
#30
n=5
k=3
print(math.factorial(n)/(math.factorial(k)*math.factorial(n-k)))
# Out:
# 10.0
