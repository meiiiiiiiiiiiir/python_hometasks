# %%
#1
def analyze_text(text):

# %%
a="ETDfghjWT098765k"
a=a.lower()
b=""
for i in range(len(a)):
    if not a[i].isdigit():
        b=b+a[i]
print(b)
b=set(b)
c=""
for i in range(len(b)):
    if b[i]  not in "qwrtpsdfghjklzxcvbnm":
        c=c+b[i]
print(c)
# Out:
# etdfghjwtk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       9 c=""
#      10 for i in range(len(b)):
# ---> 11     if b[i]  not in "qwrtpsdfghjklzxcvbnm":
#      12         c=c+b[i]
#      13 print(c)
#
# TypeError: 'set' object is not subscriptable
